# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df = pd.read_stata('cars.dta')

# %%
df.head()
# Out:
#    year  domestic  imported  tot_sales
# 0  2019    229887    209949     439836
# 1  2018    237854    197281     435135
# 2  2017    259138    185531     444669
# 3  2016    269232    170397     439629
# 4  2015    266095    154685     420780

# %%
df.sample(10)
# Out:
#     year  domestic  imported  tot_sales
# 12  2007    271683     55094     326777
# 16  2003    356994     56747     413741
# 21  1998    398576     75493     474069
# 10  2009    234018     60405     294423
# 3   2016    269232    170397     439629
# 5   2014    287665    136164     423829
# 17  2002    345211     53671     398882
# 0   2019    229887    209949     439836
# 22  1997    377403    101718     479121
# 8   2011    286248     92043     378291

# %%
# probably not what you want 
df.plot()

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
df = df.sort_values('year')

# %%
# plt.style.use('ggplot')
# plt.style.available
df.plot.scatter(x='domestic', y = 'imported')

# %%
df.plot.bar(x='year', y=['imported', 'domestic'])

# %%
df.plot.barh(x='year', y=['imported', 'domestic'], stacked=True, alpha=0.5)

# %%
df.plot()

# %%
df.plot(x='year', y=['imported', 'domestic'])

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
df1 = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
   ....:                   columns=['A', 'B', 'C', 'D'],
   ....:                   index=np.arange(0, 100, 10))

# %%
df1.plot()
plt.savefig("fig3.png")

# %%
df.plot.kdensity(x='year', y=['imported', 'domestic'], alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-2af51b81c333> in <module>
# ----> 1 df.plot.kdensity(x='year', y=['imported', 'domestic'], alpha=0.5)
#
# AttributeError: 'PlotAccessor' object has no attribute 'kdensity'

# %%
df.plot.density(y=['imported', 'domestic'], alpha=0.5)
